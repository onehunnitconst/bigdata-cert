# %%
import pandas as pd
df = pd.DataFrame({
    'Caffeine(mg)': [
        94.2, 93.7, 95.5, 93.9, 94.0, 95.2, 94.7, 93.5, 92.8, 94.4,
        93.8, 94.6, 93.3, 95.1, 94.3, 94.9, 93.9, 94.8, 95.0, 94.2,
        93.7, 94.4, 95.1, 94.0, 93.6
    ]
})

# %%
print(df.mean())
# Out:
# Caffeine(mg)    94.264
# dtype: float64

# %%
from scipy import stats
stats.shapiro(df['Caffeine(mg)'])
# Out:
# ShapiroResult(statistic=np.float64(0.9826578166170541), pvalue=np.float64(0.9322031137747027))

# %%
statistics, pvalue = stats.ttest_1samp(df['Caffeine(mg)'], 95, alternative='less')
print("{:.10f}".format(pvalue))
# Out:
# 0.0000058687
