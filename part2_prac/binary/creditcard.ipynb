# %%
import pandas as pd

train = pd.read_csv('./data/creditcard_train.csv')
test  = pd.read_csv('./data/creditcard_test.csv')

# %%
print('train: ', train.shape)
print('test : ', test.shape)
# Out:
# train:  (25519, 19)
# test :  (7591, 18)

# %%
# 1. EDA

train.head(1)
# Out:
# (25519, 19)

# %%
test.head(1)
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5037176           F            N               Y             1
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE NAME_EDUCATION_TYPE  \
# 0          337500.0  Commercial associate    Higher education
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  Single / not married  House / apartment      -14408           -431
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                0           0           0     Accountants
#
#    CNT_FAM_MEMBERS
# 0              2.0

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25519 entries, 0 to 25518
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   25519 non-null  int64
#  1   CODE_GENDER          25519 non-null  str
#  2   FLAG_OWN_CAR         25519 non-null  str
#  3   FLAG_OWN_REALTY      25519 non-null  str
#  4   CNT_CHILDREN         25519 non-null  int64
#  5   AMT_INCOME_TOTAL     25519 non-null  float64
#  6   NAME_INCOME_TYPE     25519 non-null  str
#  7   NAME_EDUCATION_TYPE  25519 non-null  str
#  8   NAME_FAMILY_STATUS   25519 non-null  str
#  9   NAME_HOUSING_TYPE    25519 non-null  str
#  10  DAYS_BIRTH           25519 non-null  int64
#  11  DAYS_EMPLOYED        25519 non-null  int64
#  12  FLAG_MOBIL           25519 non-null  int64
#  13  FLAG_WORK_PHONE      25519 non-null  int64
#  14  FLAG_PHONE           25519 non-null  int64
#  15  FLAG_EMAIL           25519 non-null  int64
#  16  OCCUPATION_TYPE      17543 non-null  str
#  17  CNT_FAM_MEMBERS      25519 non-null  float64
#  18  STATUS               25519 non-null  int64
# dtypes: float64(2), int64(9), str(8)
# memory usage: 3.7 MB

# %%
train.isnull().sum()
# Out:
# ID                        0
# CODE_GENDER               0
# FLAG_OWN_CAR              0
# FLAG_OWN_REALTY           0
# CNT_CHILDREN              0
# AMT_INCOME_TOTAL          0
# NAME_INCOME_TYPE          0
# NAME_EDUCATION_TYPE       0
# NAME_FAMILY_STATUS        0
# NAME_HOUSING_TYPE         0
# DAYS_BIRTH                0
# DAYS_EMPLOYED             0
# FLAG_MOBIL                0
# FLAG_WORK_PHONE           0
# FLAG_PHONE                0
# FLAG_EMAIL                0
# OCCUPATION_TYPE        7976
# CNT_FAM_MEMBERS           0
# STATUS                    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
train.dropna(subset=['OCCUPATION_TYPE'], inplace=True)

# %%
print(train.shape)
# Out:
# (17543, 19)

# %%
target = train.pop('STATUS')

# %%
train = pd.get_dummies(train)
test = pd.get_dummies(test)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(train, target, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=0)
rf.fit(X_tr, y_tr)
pred = rf.predict(X_val)

# %%
from sklearn.metrics import f1_score

score = f1_score(y_val, pred)
print("f1 score: ", score)
# Out:
# f1 score:  0.22018348623853212

# %%
pred = rf.predict(test)
submit = pd.DataFrame({'pred': pred})
submit.to_csv("creditcard_result.csv", index=False)
