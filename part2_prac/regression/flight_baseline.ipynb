# %%
import pandas as pd

train = pd.read_csv("./data/flight_train.csv")
test  = pd.read_csv("./data/flight_test.csv")

# %%
print(train.shape)
print(test.shape)
# Out:
# (10505, 11)
# (4502, 10)

# %%
train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10505 entries, 0 to 10504
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   airline           10505 non-null  str
#  1   flight            10505 non-null  str
#  2   source_city       10505 non-null  str
#  3   departure_time    10505 non-null  str
#  4   stops             10505 non-null  str
#  5   arrival_time      10505 non-null  str
#  6   destination_city  10505 non-null  str
#  7   class             10505 non-null  str
#  8   duration          10505 non-null  float64
#  9   days_left         10505 non-null  int64
#  10  price             10505 non-null  int64
# dtypes: float64(1), int64(2), str(8)
# memory usage: 902.9 KB

# %%
train.describe()
# Out:
#            duration     days_left          price
# count  10505.000000  10505.000000   10505.000000
# mean      12.225536     26.050547   20650.139838
# std        7.182264     13.539947   22570.924117
# min        0.830000      1.000000    1105.000000
# 25%        6.750000     15.000000    4755.000000
# 50%       11.250000     26.000000    7455.000000
# 75%       16.170000     38.000000   42457.000000
# max       40.500000     49.000000  110936.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 train.describe(include='O')
#
# File ~/Workspace/study/bigdata-cert/.venv/lib/python3.14/site-packages/pandas/core/generic.py:11426, in NDFrame.describe(self, percentiles, include, exclude)
#   11422         50%            NaN      2.0
#   11423         75%            NaN      2.5
#   11424         max            NaN      3.0
#   11425         """
# > 11426         return describe_ndframe(
#   11427             obj=self,
#   11428             include=include,
#   11429             exclude=exclude,
#
# File ~/Workspace/study/bigdata-cert/.venv/lib/python3.14/site-packages/pandas/core/methods/describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File ~/Workspace/study/bigdata-cert/.venv/lib/python3.14/site-packages/pandas/core/methods/describe.py:167, in DataFrameDescriber.describe(self, percentiles)
#     166 def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 167     data = self._select_data()
#     169     ldesc: list[Series] = []
#     170     for _, series in data.items():
#
# File ~/Workspace/study/bigdata-cert/.venv/lib/python3.14/site-packages/pandas/core/methods/describe.py:204, in DataFrameDescriber._select_data(self)
#     202     if len(data.columns) == 0:
#     203         msg = "No columns match the specified include or exclude data types"
# --> 204         raise ValueError(msg)
#     205 return data
#
# ValueError: No columns match the specified include or exclude data types

# %%
test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4502 entries, 0 to 4501
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   airline           4502 non-null   str
#  1   flight            4502 non-null   str
#  2   source_city       4502 non-null   str
#  3   departure_time    4502 non-null   str
#  4   stops             4502 non-null   str
#  5   arrival_time      4502 non-null   str
#  6   destination_city  4502 non-null   str
#  7   class             4502 non-null   str
#  8   duration          4502 non-null   float64
#  9   days_left         4502 non-null   int64
# dtypes: float64(1), int64(1), str(8)
# memory usage: 351.8 KB

# %%
train = train.drop('flight', axis=1)
test = test.drop('flight', axis=1)

target = train.pop('price')

train = pd.get_dummies(train)
test = pd.get_dummies(test)

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(train, target, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=0)
rf.fit(X_tr, y_tr)
# Out:
# RandomForestRegressor(random_state=0)

# %%
pred = rf.predict(X_val)

# %%
from sklearn.metrics import root_mean_squared_error

score = root_mean_squared_error(y_val, pred)
print(score)
# Out:
# 4376.841613585934

# %%
pred = rf.predict(test)
submit = pd.DataFrame({'pred': pred})
submit.to_csv("./submit/flight_baseline_result.csv", index=False)
